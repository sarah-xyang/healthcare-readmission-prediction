# %% [markdown]
# # 03 — Model Training & Evaluation
#
# **Business purpose:** This notebook trains the readmission risk model and measures how well it performs. A model that flags too few high-risk patients misses intervention opportunities; one that flags too many wastes clinical resources. We evaluate the model with metrics that reflect this trade-off, and we use SHAP to explain *why* the model scores each patient the way it does.

# %%
# TODO: Train model and evaluate performance
